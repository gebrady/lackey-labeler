# %% [markdown]
# # PoCoPet Labeler for XRF Beads with a graphical user interface
# ### With the amount of XRF glass and samples generated in the Pomona lab, it would be helpful to increase efficiency in label creation using a tabular format. Currently, data are entered into Microsoft Word files one line at a time by hand, creating opportunities for human error in data entry and general slowness. Expediting the data entry through an automated method ensures accurate data transfer from field notes, chemical databases, and other sources of stored information.
#
# ### Although the data we gather and notate in the Pomona lab generally require a human to intiate their presence in catalogs, we can minimize the amount of times these data are transferred by hand to decrease the potential for accidental skewing and errors. Likewise, data entry in a tabular format like Excel better allows the user to follow along with their data, i.e. match consistency among attributes of the same type, see the entire catalog in one view, or directly import columns of data from existing archives of chemical or descriptive data; on the other hand, entering data line-by-line, cell-by-cell in a word document prohibits checks in consistency.
#
# ### Thus, the following packages were developed to streamline the process from data table to table of labels. The following workflow is carried out:
#
# ##### (1) Tabular data are uploaded
# ##### (2) Unique suites contained in the data are identified and enumerated
# ##### (3) User selects colors for each suite in the data
# ##### (4) User-given attributes are used alongside the tabular data table to populate a Word template.
#
# ### Lastly, the use of a graphical user interface encourages petrologists, geologists, etc. of any coding ability to operate this beta-level software.
#
# ##### Disclaimer: While the code runs smoothly and has been tested many times, the author has not corroborated efficiency with other developers to create a vastly applicable code with many features. Potential updates to the design are written in the code files as comments.

# %%
# if using a python interpreter, type and run the following two cells #
from SuiteColorChooser import ColorWheel #import the class

# %%
cw = ColorWheel() #initiate an object of the type ColorWheel
cw.mainloop()
# At this step, the GUI should pop up.
# Out:
#        Sample   Latitude   Longitude     Lithology    Suite   Collector  \
# 0    Sample 1  34.099895 -117.713462       granite  Suite 1      Lackey
# 1    Sample 2  34.099895 -117.713462        basalt  Suite 2       Moore
# 2    Sample 3  34.099895 -117.713462  lecuogranite  Suite 1  Prokopenko
# 3    Sample 4  34.099895 -117.713462           Gdt  Suite 2      Harris
# 4    Sample 5  34.099895 -117.713462         BtGdt  Suite 3      Lackey
# 5    Sample 6  34.099895 -117.713462       Ashflow  Suite 3       Moore
# 6    Sample 7  34.099895 -117.713462          tuff  Suite 2  Prokopenko
# 7    Sample 8  34.099895 -117.713462     granitoid  Suite 2      Harris
# 8    Sample 9  34.099895 -117.713462        dacite  Suite 6      Lackey
# 9   Sample 10  34.099895 -117.713462       diorite  Suite 2       Moore
# 10  Sample 11  34.099895 -117.713462      andesite  Suite 3  Prokopenko
# 11  Sample 12  34.099895 -117.713462      rhyolite  Suite 2      Harris
# 12  Sample 13  34.099895 -117.713462        gabbro  Suite 1      Lackey
# 13  Sample 14  34.099895 -117.713462       syenite  Suite 1       Moore
# 14  Sample 15  34.099895 -117.713462     A-granite  Suite 1  Prokopenko
# 15  Sample 16  34.099895 -117.713462     sandstone  Suite 2      Harris
# 16  Sample 17  34.099895 -117.713462         shale  Suite 3      Lackey
# 17  Sample 18  34.099895 -117.713462         wacke  Suite 2       Moore
# 18  Sample 19  34.099895 -117.713462         chert  Suite 4  Prokopenko
# 19  Sample 20  34.099895 -117.713462           BIF  Suite 2      Harris
# 20  Sample 21  34.099895 -117.713462         Skarn  Suite 5      Lackey
# 21  Sample 22  34.099895 -117.713462     Biotitite  Suite 2       Moore
# 22  Sample 23  34.099895 -117.713462    Wlded Tuff  Suite 3  Prokopenko
# 23  Sample 24  34.099895 -117.713462        Arkose  Suite 3      Harris
#
#       Misc
# 0    apple
# 1   banana
# 2     rose
# 3   garden
# 4     duck
# 5      red
# 6    grass
# 7     leaf
# 8    bagel
# 9    pasta
# 10   bread
# 11    mozz
# 12   music
# 13     rap
# 14    rock
# 15    dust
# 16     ash
# 17   grain
# 18   truss
# 19  bridge
# 20   cross
# 21    lake
# 22   river
# 23   water
# Shown above: /Users/Graham/scripts/LackeyLabeler/data/TemplateData.xlsx
# #0432ff  added to suite color list.
# #ff40ff  added to suite color list.
# #0432ff  added to suite color list.
# #ff40ff  added to suite color list.
# #4e8f00  added to suite color list.
# #8df900  added to suite color list.
# [('Suite 1', (4, 50, 255)), ('Suite 2', (255, 64, 255)), ('Suite 3', (4, 50, 255)), ('Suite 6', (255, 64, 255)), ('Suite 4', (78, 143, 0)), ('Suite 5', (141, 249, 0))]
# 0
# suite                     Suite 1
# sample                   Sample 1
# lith                      granite
# latlong    34.09989°, -117.71346°
# misc2               apple; Lackey
# Name: 0, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 1
# changing color
# color changed
# row written: Suite 1
# 1
# adding data:  Sample 1
# row written: Sample 1
# 2
# adding data:  granite
# row written: granite
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  apple; Lackey
# row written: apple; Lackey
# 1
# suite                     Suite 2
# sample                   Sample 2
# lith                       basalt
# latlong    34.09989°, -117.71346°
# misc2               banana; Moore
# Name: 1, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 2
# changing color
# color changed
# row written: Suite 2
# 1
# adding data:  Sample 2
# row written: Sample 2
# 2
# adding data:  basalt
# row written: basalt
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  banana; Moore
# row written: banana; Moore
# 2
# suite                     Suite 1
# sample                   Sample 3
# lith                 lecuogranite
# latlong    34.09989°, -117.71346°
# misc2            rose; Prokopenko
# Name: 2, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 1
# changing color
# color changed
# row written: Suite 1
# 1
# adding data:  Sample 3
# row written: Sample 3
# 2
# adding data:  lecuogranite
# row written: lecuogranite
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  rose; Prokopenko
# row written: rose; Prokopenko
# 3
# suite                     Suite 2
# sample                   Sample 4
# lith                          Gdt
# latlong    34.09989°, -117.71346°
# misc2              garden; Harris
# Name: 3, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 2
# changing color
# color changed
# row written: Suite 2
# 1
# adding data:  Sample 4
# row written: Sample 4
# 2
# adding data:  Gdt
# row written: Gdt
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  garden; Harris
# row written: garden; Harris
# 4
# suite                     Suite 3
# sample                   Sample 5
# lith                        BtGdt
# latlong    34.09989°, -117.71346°
# misc2                duck; Lackey
# Name: 4, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 3
# changing color
# color changed
# row written: Suite 3
# 1
# adding data:  Sample 5
# row written: Sample 5
# 2
# adding data:  BtGdt
# row written: BtGdt
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  duck; Lackey
# row written: duck; Lackey
# 5
# suite                     Suite 3
# sample                   Sample 6
# lith                      Ashflow
# latlong    34.09989°, -117.71346°
# misc2                  red; Moore
# Name: 5, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 3
# changing color
# color changed
# row written: Suite 3
# 1
# adding data:  Sample 6
# row written: Sample 6
# 2
# adding data:  Ashflow
# row written: Ashflow
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  red; Moore
# row written: red; Moore
# 6
# suite                     Suite 2
# sample                   Sample 7
# lith                         tuff
# latlong    34.09989°, -117.71346°
# misc2           grass; Prokopenko
# Name: 6, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 2
# changing color
# color changed
# row written: Suite 2
# 1
# adding data:  Sample 7
# row written: Sample 7
# 2
# adding data:  tuff
# row written: tuff
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  grass; Prokopenko
# row written: grass; Prokopenko
# 7
# suite                     Suite 2
# sample                   Sample 8
# lith                    granitoid
# latlong    34.09989°, -117.71346°
# misc2                leaf; Harris
# Name: 7, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 2
# changing color
# color changed
# row written: Suite 2
# 1
# adding data:  Sample 8
# row written: Sample 8
# 2
# adding data:  granitoid
# row written: granitoid
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  leaf; Harris
# row written: leaf; Harris
# 8
# suite                     Suite 6
# sample                   Sample 9
# lith                       dacite
# latlong    34.09989°, -117.71346°
# misc2               bagel; Lackey
# Name: 8, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 6
# changing color
# color changed
# row written: Suite 6
# 1
# adding data:  Sample 9
# row written: Sample 9
# 2
# adding data:  dacite
# row written: dacite
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  bagel; Lackey
# row written: bagel; Lackey
# 9
# suite                     Suite 2
# sample                  Sample 10
# lith                      diorite
# latlong    34.09989°, -117.71346°
# misc2                pasta; Moore
# Name: 9, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 2
# changing color
# color changed
# row written: Suite 2
# 1
# adding data:  Sample 10
# row written: Sample 10
# 2
# adding data:  diorite
# row written: diorite
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  pasta; Moore
# row written: pasta; Moore
# 10
# suite                     Suite 3
# sample                  Sample 11
# lith                     andesite
# latlong    34.09989°, -117.71346°
# misc2           bread; Prokopenko
# Name: 10, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 3
# changing color
# color changed
# row written: Suite 3
# 1
# adding data:  Sample 11
# row written: Sample 11
# 2
# adding data:  andesite
# row written: andesite
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  bread; Prokopenko
# row written: bread; Prokopenko
# 11
# suite                     Suite 2
# sample                  Sample 12
# lith                     rhyolite
# latlong    34.09989°, -117.71346°
# misc2                mozz; Harris
# Name: 11, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 2
# changing color
# color changed
# row written: Suite 2
# 1
# adding data:  Sample 12
# row written: Sample 12
# 2
# adding data:  rhyolite
# row written: rhyolite
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  mozz; Harris
# row written: mozz; Harris
# 12
# suite                     Suite 1
# sample                  Sample 13
# lith                       gabbro
# latlong    34.09989°, -117.71346°
# misc2               music; Lackey
# Name: 12, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 1
# changing color
# color changed
# row written: Suite 1
# 1
# adding data:  Sample 13
# row written: Sample 13
# 2
# adding data:  gabbro
# row written: gabbro
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  music; Lackey
# row written: music; Lackey
# 13
# suite                     Suite 1
# sample                  Sample 14
# lith                      syenite
# latlong    34.09989°, -117.71346°
# misc2                  rap; Moore
# Name: 13, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 1
# changing color
# color changed
# row written: Suite 1
# 1
# adding data:  Sample 14
# row written: Sample 14
# 2
# adding data:  syenite
# row written: syenite
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  rap; Moore
# row written: rap; Moore
# 14
# suite                     Suite 1
# sample                  Sample 15
# lith                    A-granite
# latlong    34.09989°, -117.71346°
# misc2            rock; Prokopenko
# Name: 14, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 1
# changing color
# color changed
# row written: Suite 1
# 1
# adding data:  Sample 15
# row written: Sample 15
# 2
# adding data:  A-granite
# row written: A-granite
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  rock; Prokopenko
# row written: rock; Prokopenko
# 15
# suite                     Suite 2
# sample                  Sample 16
# lith                    sandstone
# latlong    34.09989°, -117.71346°
# misc2                dust; Harris
# Name: 15, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 2
# changing color
# color changed
# row written: Suite 2
# 1
# adding data:  Sample 16
# row written: Sample 16
# 2
# adding data:  sandstone
# row written: sandstone
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  dust; Harris
# row written: dust; Harris
# 16
# suite                     Suite 3
# sample                  Sample 17
# lith                        shale
# latlong    34.09989°, -117.71346°
# misc2                 ash; Lackey
# Name: 16, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 3
# changing color
# color changed
# row written: Suite 3
# 1
# adding data:  Sample 17
# row written: Sample 17
# 2
# adding data:  shale
# row written: shale
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  ash; Lackey
# row written: ash; Lackey
# 17
# suite                     Suite 2
# sample                  Sample 18
# lith                        wacke
# latlong    34.09989°, -117.71346°
# misc2                grain; Moore
# Name: 17, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 2
# changing color
# color changed
# row written: Suite 2
# 1
# adding data:  Sample 18
# row written: Sample 18
# 2
# adding data:  wacke
# row written: wacke
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  grain; Moore
# row written: grain; Moore
# 18
# suite                     Suite 4
# sample                  Sample 19
# lith                        chert
# latlong    34.09989°, -117.71346°
# misc2           truss; Prokopenko
# Name: 18, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 4
# changing color
# color changed
# row written: Suite 4
# 1
# adding data:  Sample 19
# row written: Sample 19
# 2
# adding data:  chert
# row written: chert
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  truss; Prokopenko
# row written: truss; Prokopenko
# 19
# suite                     Suite 2
# sample                  Sample 20
# lith                          BIF
# latlong    34.09989°, -117.71346°
# misc2              bridge; Harris
# Name: 19, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 2
# changing color
# color changed
# row written: Suite 2
# 1
# adding data:  Sample 20
# row written: Sample 20
# 2
# adding data:  BIF
# row written: BIF
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  bridge; Harris
# row written: bridge; Harris
# 20
# suite                     Suite 5
# sample                  Sample 21
# lith                        Skarn
# latlong    34.09989°, -117.71346°
# misc2               cross; Lackey
# Name: 20, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 5
# changing color
# color changed
# row written: Suite 5
# 1
# adding data:  Sample 21
# row written: Sample 21
# 2
# adding data:  Skarn
# row written: Skarn
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  cross; Lackey
# row written: cross; Lackey
# 21
# suite                     Suite 2
# sample                  Sample 22
# lith                    Biotitite
# latlong    34.09989°, -117.71346°
# misc2                 lake; Moore
# Name: 21, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 2
# changing color
# color changed
# row written: Suite 2
# 1
# adding data:  Sample 22
# row written: Sample 22
# 2
# adding data:  Biotitite
# row written: Biotitite
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  lake; Moore
# row written: lake; Moore
# 22
# suite                     Suite 3
# sample                  Sample 23
# lith                   Wlded Tuff
# latlong    34.09989°, -117.71346°
# misc2           river; Prokopenko
# Name: 22, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 3
# changing color
# color changed
# row written: Suite 3
# 1
# adding data:  Sample 23
# row written: Sample 23
# 2
# adding data:  Wlded Tuff
# row written: Wlded Tuff
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  river; Prokopenko
# row written: river; Prokopenko
# 23
# suite                     Suite 3
# sample                  Sample 24
# lith                       Arkose
# latlong    34.09989°, -117.71346°
# misc2               water; Harris
# Name: 23, dtype: object
# ['Suite', 'Sample', 'Lithology', 'LatLong', 'Misc']
# 0
# adding data:  Suite 3
# changing color
# color changed
# row written: Suite 3
# 1
# adding data:  Sample 24
# row written: Sample 24
# 2
# adding data:  Arkose
# row written: Arkose
# 3
# adding data:  34.09989°, -117.71346°
# row written: 34.09989°, -117.71346°
# 4
# adding data:  water; Harris
# row written: water; Harris
# writing document
# document written
# File written to: /Users/Graham/scripts/LackeyLabeler/TemplateData_Labels.docx

# %%
# Alternate Command Line Script #
# use this if running from the terminal or powershell. In some ways, this is easiest. #
python SuiteColorChooser.py

# %% [markdown]
# ![Figure 1](jupyterimg/figure1.png "Figure 1")
# Figure 1: Just this section pops up to begin with. Click to upload a data file. Currently the app accepts .xlsx, .csv, and .txt tab-delimitted text.

# %% [markdown]
# ![Figure 2](jupyterimg/figure2.png "Figure 2")
# Figure 2: Browse your documents to upload the proper file. Be sure to use the same column names as the template file stored in TemplateData.xlsx and other files. __In this version__, the app's code can only decipher data files with at least these column names present. Future versions will increase variability with this. The default directory is the working directory from which you ran the program to begin with; other directories are still accessibile by browsing. The outfile will be written to the working directory regardless of where the data area from.

# %% [markdown]
# ![Figure 3](jupyterimg/figure3.png "Figure 3")
# Figure 3: The data have been properly read and you are ready to begin designating colors using the swatches that pop up. Once you've selected one, click the choose color button again.

# %% [markdown]
# ![Figure 4](jupyterimg/figure4.png "Figure 4")
# Figure 4: The suite for which you just chose a color should be listed in the color you chose for it. Currently, only the preceding suite choice is displayed; a future version ideally will list all suites and their colors so that the user does not accidently repeat colors without knowing what they have already chosen.

# %% [markdown]
# ![Figure 5](jupyterimg/figure5.png "Figure 5")
# Figure 5: When finished with all identified unique suites, a list of all suites should be displayed. This means you are ready to compile the data and produce your labels. Click!

# %% [markdown]
# ![Figure 6](jupyterimg/figure6.png "Figure 6")
# Figure 6: Watch for a surprise in one of the fun images that pops up when you've successfully compiled the data! Find the outfile in your folders and get printing/cutting.

# %% [markdown]
# ### Click the Quit button to end the app's run and enjoy your new .docx file. Convert it to .pdf if you'd like.
